# %%
#匯入必要的library
from __future__ import print_function
from imutils import paths
from scipy.io import loadmat
from skimage import io
import argparse
import dlib
import cv2
import re
import xml.etree.ElementTree as ET
import os

# %%
options = dlib.simple_object_detector_training_options()
#存放相片圖檔
turtleIslandImages = [] 
turtleIslandLeftImages = []
turtleIslandTopImages = []
#存放Annotations
turtleIslandBoxes = [] 
turtleIslandLeftBoxes = []
turtleIslandTopBoxes = []
 
#依序處理path下的每張圖片
for imagePath in paths.list_images("yilan/turtleIsland/turtleIslandPic"):
    imageID = imagePath[imagePath.rfind("/") + 1:].replace(".jpg", "")
#     print(imagePath)
    
    #read XML file      
    xmlPath = "yilan/turtleIsland/turtleIslandLabel/" + imageID + ".xml"
    #print(xmlPath)
    tree = ET.parse(xmlPath)
    root = tree.getroot()
    for xml in root.findall('object'):
        detector = xml.find("name").text
        x = int(xml.find("bndbox").find("xmin").text)
        y = int(xml.find("bndbox").find("ymin").text)
        width = int(xml.find("bndbox").find("xmax").text) - x
        height = int(xml.find("bndbox").find("ymax").text) - y
        ratio = height / width
        pixel = height * height
#         print(x, y, width, height, ratio, pixel)

    #取出annotations資訊繪成矩形物件
    bb = [dlib.rectangle(left = round(x * ratio), top = y, right = height, bottom = height)]    
#     print(bb)
    #revise pic width
    img = cv2.imread(imagePath, cv2.IMREAD_UNCHANGED)
    picWidth = round(img.shape[1] * ratio)
    picHeight = img.shape[0] # keep original height
    dim = (picWidth, picHeight)

    # resize image
    resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
#     print('Original Dimensions : ', img.shape) 
#     print('Resized Dimensions : ', resized.shape)
#     print(resized)
#     print(cv2.imread(imagePath))
#     cv2.rectangle(resized, (round(x * ratio), y), (round(x * ratio) + height, y + height), (0, 255, 0), 2) 
#     cv2.imshow("Resized image", resized)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows() 

    if detector == "turtleIsland":
        #放入boxes變數中。
        if pixel > 1000:
            turtleIslandBoxes.append(bb)
            #將圖片放入images變數
            turtleIslandImages.append(cv2.imread(imagePath))
            print("Pic {}, Right saved. Box size: {}".format(imageID, height * height))
        else:
            print("pixel smaller than 400 ")
    
#     elif pixel >= 400 & detector == "turtleIslandLeft":
#         #放入boxes變數中。
#         turtleIslandLeftBoxes.append(bb)
        
#         #將圖片放入images變數
#         turtleIslandLeftImages.append(cv2.imread(imagePath))
#         print("Pic {}, Left saved.".format(imageID))
    
#     elif pixel >= 400 & detector == "turtleIslandTop":
#         #放入boxes變數中。
#         turtleIslandTopBoxes.append(bb)
        
#         #將圖片放入images變數
#         turtleIslandTopImages.append(cv2.imread(imagePath))
        
#         print("Pic {}, Top saved.".format(imageID))
        
#     else:
#         print("not exit")
# Out:
# Pic 857, Right saved. Box size: 1849
# pixel smaller than 400
# pixel smaller than 400
# Pic 185, Right saved. Box size: 1936
# Pic 242, Right saved. Box size: 4489
# Pic 171, Right saved. Box size: 3025
# Pic 219, Right saved. Box size: 2916
# Pic 989, Right saved. Box size: 3969
# Pic 786, Right saved. Box size: 9025
# Pic 021, Right saved. Box size: 5041
# pixel smaller than 400
# Pic 275, Right saved. Box size: 1521
# Pic 049, Right saved. Box size: 6724
# pixel smaller than 400
# Pic 474, Right saved. Box size: 10404
# Pic 829, Right saved. Box size: 7921
# pixel smaller than 400
# Pic 080, Right saved. Box size: 2209
# Pic 001, Right saved. Box size: 3136
# Pic 307, Right saved. Box size: 1024
# Pic 283, Right saved. Box size: 3364
# Pic 090, Right saved. Box size: 4225
# pixel smaller than 400
# Pic 125, Right saved. Box size: 2500
# Pic 157, Right saved. Box size: 9409
# Pic 1003, Right saved. Box size: 5329
# Pic 148, Right saved. Box size: 4356
# Pic 156, Right saved. Box size: 1156
# pixel smaller than 400
# Pic 067, Right saved. Box size: 2601
# pixel smaller than 400
# Pic 127, Right saved. Box size: 7056
# Pic 133, Right saved. Box size: 8281
# Pic 272, Right saved. Box size: 6084
# Pic 033, Right saved. Box size: 1521
# Pic 217, Right saved. Box size: 4761
# Pic 284, Right saved. Box size: 3249
# pixel smaller than 400
# pixel smaller than 400
# Pic 014, Right saved. Box size: 2209
# pixel smaller than 400
# pixel smaller than 400
# Pic 093, Right saved. Box size: 2209
# Pic 233, Right saved. Box size: 5329
# Pic 126, Right saved. Box size: 5776
# Pic 237, Right saved. Box size: 1156
# Pic 262, Right saved. Box size: 4761
# pixel smaller than 400
# Pic 260, Right saved. Box size: 9604
# Pic 843, Right saved. Box size: 4356
# Pic 575, Right saved. Box size: 3844
# Pic 246, Right saved. Box size: 3481
# pixel smaller than 400
# Pic 231, Right saved. Box size: 4624
# Pic 223, Right saved. Box size: 2209
# Pic 259, Right saved. Box size: 5476
# pixel smaller than 400
# Pic 306, Right saved. Box size: 4096
# pixel smaller than 400
# Pic 169, Right saved. Box size: 1296
# Pic 222, Right saved. Box size: 6084
# pixel smaller than 400
# Pic 073, Right saved. Box size: 1225
# Pic 273, Right saved. Box size: 2401
# Pic 263, Right saved. Box size: 8836
# Pic 107, Right saved. Box size: 16129
# pixel smaller than 400
# Pic 002, Right saved. Box size: 1369
# Pic 057, Right saved. Box size: 3721
# Pic 256, Right saved. Box size: 2116
# Pic 032, Right saved. Box size: 2116
# pixel smaller than 400
# pixel smaller than 400
# Pic 186, Right saved. Box size: 1681
# Pic 130, Right saved. Box size: 4900
# Pic 011, Right saved. Box size: 1225
# Pic 249, Right saved. Box size: 10000
# Pic 173, Right saved. Box size: 3969
# Pic 119, Right saved. Box size: 2809
# Pic 869, Right saved. Box size: 10000
# Pic 304, Right saved. Box size: 1444
# Pic 459, Right saved. Box size: 11236
# Pic 314, Right saved. Box size: 1681
# Pic 069, Right saved. Box size: 8281
# Pic 227, Right saved. Box size: 6241
# Pic 226, Right saved. Box size: 4900
# Pic 232, Right saved. Box size: 6400
# Pic 292, Right saved. Box size: 1089
# Pic 464, Right saved. Box size: 7921
# Pic 229, Right saved. Box size: 3249
# Pic 025, Right saved. Box size: 2025
# Pic 153, Right saved. Box size: 4624
# Pic 176, Right saved. Box size: 4761
# Pic 261, Right saved. Box size: 6561
# Pic 945, Right saved. Box size: 12321
# Pic 313, Right saved. Box size: 1225
# Pic 086, Right saved. Box size: 1521
# pixel smaller than 400
# Pic 175, Right saved. Box size: 1024
# Pic 870, Right saved. Box size: 7569
# Pic 245, Right saved. Box size: 2704
# Pic 267, Right saved. Box size: 3249
# pixel smaller than 400
# Pic 285, Right saved. Box size: 3481
# Pic 234, Right saved. Box size: 4489
# Pic 003, Right saved. Box size: 1089
# Pic 302, Right saved. Box size: 2601
# Pic 072, Right saved. Box size: 10201
# Pic 819, Right saved. Box size: 9409
# Pic 110, Right saved. Box size: 2209
# Pic 850, Right saved. Box size: 8281
# pixel smaller than 400
# Pic 316, Right saved. Box size: 5625
# Pic 286, Right saved. Box size: 2209
# Pic 257, Right saved. Box size: 2304
# Pic 460, Right saved. Box size: 8100
# Pic 596, Right saved. Box size: 7225
# Pic 053, Right saved. Box size: 7921
# Pic 039, Right saved. Box size: 1156
# Pic 061, Right saved. Box size: 3481
# Pic 247, Right saved. Box size: 1444
# Pic 131, Right saved. Box size: 1681
# pixel smaller than 400
# Pic 179, Right saved. Box size: 1521
# Pic 792, Right saved. Box size: 5929
# Pic 221, Right saved. Box size: 4356
# Pic 849, Right saved. Box size: 5776
# Pic 228, Right saved. Box size: 2116
# Pic 204, Right saved. Box size: 2401
# Pic 074, Right saved. Box size: 1521
# Pic 992, Right saved. Box size: 11025
# Pic 458, Right saved. Box size: 12544
# Pic 216, Right saved. Box size: 1681
# Pic 691, Right saved. Box size: 2025
# pixel smaller than 400
# Pic 035, Right saved. Box size: 1296
# Pic 026, Right saved. Box size: 3136
# Pic 177, Right saved. Box size: 1936
# pixel smaller than 400
# Pic 095, Right saved. Box size: 1296
# Pic 811, Right saved. Box size: 5625
# pixel smaller than 400
# Pic 692, Right saved. Box size: 1600
# Pic 254, Right saved. Box size: 1936
# pixel smaller than 400
# Pic 031, Right saved. Box size: 5329
# Pic 269, Right saved. Box size: 2401
# Pic 041, Right saved. Box size: 1225
# Pic 023, Right saved. Box size: 3249
# pixel smaller than 400
# Pic 258, Right saved. Box size: 5929
# Pic 278, Right saved. Box size: 4225
# pixel smaller than 400
# Pic 181, Right saved. Box size: 3969
# Pic 463, Right saved. Box size: 8464
# Pic 205, Right saved. Box size: 3721
# pixel smaller than 400
# Pic 132, Right saved. Box size: 1089
# Pic 220, Right saved. Box size: 2500
# pixel smaller than 400
# Pic 281, Right saved. Box size: 5776
# Pic 462, Right saved. Box size: 9216
# Pic 251, Right saved. Box size: 2809
# Pic 203, Right saved. Box size: 5329
# Pic 833, Right saved. Box size: 10201
# Pic 020, Right saved. Box size: 2025
# Pic 693, Right saved. Box size: 4225
# Pic 006, Right saved. Box size: 1024
# pixel smaller than 400
# pixel smaller than 400
# pixel smaller than 400
# pixel smaller than 400
# Pic 178, Right saved. Box size: 3136
# Pic 241, Right saved. Box size: 1296
# Pic 018, Right saved. Box size: 9025
# pixel smaller than 400
# pixel smaller than 400
# pixel smaller than 400
# pixel smaller than 400
# Pic 140, Right saved. Box size: 6561
# Pic 230, Right saved. Box size: 2916
# Pic 235, Right saved. Box size: 2116
# Pic 244, Right saved. Box size: 2209
# pixel smaller than 400
# Pic 015, Right saved. Box size: 3969
# Pic 165, Right saved. Box size: 14884
# pixel smaller than 400
# Pic 120, Right saved. Box size: 3025
# pixel smaller than 400
# Pic 121, Right saved. Box size: 7056
# Pic 022, Right saved. Box size: 6400
# Pic 180, Right saved. Box size: 10609
# Pic 872, Right saved. Box size: 7569
# Pic 995, Right saved. Box size: 5476
# pixel smaller than 400
# Pic 129, Right saved. Box size: 2704
# Pic 943, Right saved. Box size: 6889
# Pic 016, Right saved. Box size: 5329
# Pic 196, Right saved. Box size: 3600
# Pic 158, Right saved. Box size: 3481
# Pic 029, Right saved. Box size: 1936
# Pic 739, Right saved. Box size: 11449
# Pic 871, Right saved. Box size: 2809
# Pic 112, Right saved. Box size: 1681
# Pic 063, Right saved. Box size: 2500
# pixel smaller than 400
# Pic 027, Right saved. Box size: 2500
# Pic 106, Right saved. Box size: 5041
# Pic 078, Right saved. Box size: 1024
# Pic 655, Right saved. Box size: 3136
# Pic 084, Right saved. Box size: 4356
# Pic 927, Right saved. Box size: 2500
# pixel smaller than 400
# Pic 034, Right saved. Box size: 4761
# Pic 197, Right saved. Box size: 2401
# pixel smaller than 400
# Pic 024, Right saved. Box size: 5929
# Pic 162, Right saved. Box size: 1089
# Pic 163, Right saved. Box size: 1681
# Pic 776, Right saved. Box size: 8836
# Pic 287, Right saved. Box size: 1936
# Pic 288, Right saved. Box size: 3721
# Pic 685, Right saved. Box size: 8836
# pixel smaller than 400
# Pic 091, Right saved. Box size: 4225
# Pic 089, Right saved. Box size: 2500
# pixel smaller than 400
# Pic 996, Right saved. Box size: 3249
# Pic 937, Right saved. Box size: 4761
# Pic 183, Right saved. Box size: 1681
# pixel smaller than 400
# Pic 461, Right saved. Box size: 6724
# Pic 009, Right saved. Box size: 1156
# Pic 077, Right saved. Box size: 3025
# Pic 218, Right saved. Box size: 3600
# Pic 472, Right saved. Box size: 10201
# Pic 059, Right saved. Box size: 6724
# Pic 887, Right saved. Box size: 8281
# Pic 134, Right saved. Box size: 10000
# Pic 083, Right saved. Box size: 5476
# Pic 103, Right saved. Box size: 7569
# Pic 143, Right saved. Box size: 1849
# Pic 115, Right saved. Box size: 7225
# Pic 224, Right saved. Box size: 1681
# Pic 868, Right saved. Box size: 10404
# Pic 117, Right saved. Box size: 7396
# Pic 055, Right saved. Box size: 9216
# Pic 282, Right saved. Box size: 3136
# Pic 309, Right saved. Box size: 6084
# Pic 395, Right saved. Box size: 16900
# Pic 005, Right saved. Box size: 2304
# pixel smaller than 400
# Pic 070, Right saved. Box size: 8281
# pixel smaller than 400
# Pic 902, Right saved. Box size: 5776
# Pic 010, Right saved. Box size: 4489
# Pic 921, Right saved. Box size: 3844
# Pic 071, Right saved. Box size: 11025

# %%
#丟入三個參數開始訓練
print("[INFO] training detector...")
detector = dlib.train_simple_object_detector(turtleIslandImages, turtleIslandBoxes, options)
 
# 將訓練結果匯出到檔案
print("[INFO] dumping classifier to file...")
# regex = re.compile(r'/.+')
# output = regex.findall(args["class"])[0].replace("/","")
# detector.save("output/" + output)
detector.save("output/" + "turtleIslandTop")

# 圖形化顯示Histogram of Oriented Gradients（簡稱HOG）
win = dlib.image_window()
win.set_image(detector)
dlib.hit_enter_to_continue()
# Out:
# [INFO] training detector...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-b3c0d61f5f3b> in <module>
#       1 #丟入三個參數開始訓練
#       2 print("[INFO] training detector...")
# ----> 3 detector = dlib.train_simple_object_detector(turtleIslandImages, turtleIslandBoxes, options)
#       4
#       5 # 將訓練結果匯出到檔案
#
# RuntimeError:
# Error! An impossible set of object boxes was given for training. All the boxes
# need to have a similar aspect ratio and also not be smaller than about 400
# pixels in area.

# %%
import cv2
 
img = cv2.imread('yilan/turtleIsland/turtleIslandPic/001.jpg', cv2.IMREAD_UNCHANGED)
xml = "yilan/turtleIsland/turtleIslandLabel/001.xml"
tree = ET.parse(xml)
root = tree.getroot()
for size in root.findall('object'):
    x = int(size.find("bndbox").find("xmin").text)
    y = int(size.find("bndbox").find("ymin").text)
    width = int(size.find("bndbox").find("xmax").text) - x
    height = int(size.find("bndbox").find("ymax").text) - y
    ratio = height / width
    print(x, y, width, height, ratio)
    
print('Original Dimensions : ', img.shape) 

picWidth = round(img.shape[1] * ratio)
print(picWidth)
picHeight = img.shape[0] # keep original height
dim = (widthPic, picHeight)
 
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ', resized.shape)

cv2.rectangle(resized, (round(x * ratio), y), (round(x * ratio) + height, y + height), (0, 255, 0), 2) 
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# no resize
options = dlib.simple_object_detector_training_options()
#存放相片圖檔
turtleIslandImages = [] 
turtleIslandLeftImages = []
turtleIslandTopImages = []
#存放Annotations
turtleIslandBoxes = [] 
turtleIslandLeftBoxes = []
turtleIslandTopBoxes = []
 
#依序處理path下的每張圖片
for imagePath in paths.list_images("yilan/turtleIsland/turtleIslandPic"):
    imageID = imagePath[imagePath.rfind("/") + 1:].replace(".jpg", "")
    #print(imagePath)
    
    #read XML file      
    xmlPath = "yilan/turtleIsland/turtleIslandLabel/" + imageID + ".xml"
    #print(xmlPath)
    tree = ET.parse(xmlPath)
    root = tree.getroot()
    for xml in root.findall('object'):
        detector = xml.find("name").text
        x = int(xml.find("bndbox").find("xmin").text)
        y = int(xml.find("bndbox").find("ymin").text)
        width = int(xml.find("bndbox").find("xmax").text) - x
        height = int(xml.find("bndbox").find("ymax").text) - y
        ratio = height / width
        print(ratio)
        print(width*height)
        #print(x, y, width, height)
    #取出annotations資訊繪成矩形物件
#     bb = [dlib.rectangle(left = x, top = y, right = width, bottom = height)]
    
#     if detector == "turtleIsland":
#         #放入boxes變數中。
#         turtleIslandBoxes.append(bb)
#         #將圖片放入images變數
#         turtleIslandImages.append(io.imread(imagePath))
#         print("Pic {}, Right saved.".format(imageID))
    
#     elif detector == "turtleIslandLeft":
#         #放入boxes變數中。
#         turtleIslandLeftBoxes.append(bb)
        
#         #將圖片放入images變數
#         turtleIslandLeftImages.append(io.imread(imagePath))
#         print("Pic {}, Left saved.".format(imageID))
    
#     elif detector == "turtleIslandTop":
#         #放入boxes變數中。
#         turtleIslandTopBoxes.append(bb)
        
#         #將圖片放入images變數
#         turtleIslandTopImages.append(io.imread(imagePath))
        
#         print("Pic {}, Top saved.".format(imageID))
        
#     else:
#         print("not exit")

# %%
for path in os.listdir("turtleIslandLabel"):
    filePath = os.path.dirname("turtleIslandLabel/") + "/" + path
    print(filePath)
    tree = ET.parse(filePath)
    root = tree.getroot()
    for size in root.findall('object'):
        x = int(size.find("bndbox").find("xmin").text)
        y = int(size.find("bndbox").find("ymin").text)
        width = int(size.find("bndbox").find("xmax").text) - x
        height = int(size.find("bndbox").find("ymax").text) - y
        print(x, y, width, height)

# %%
cv2.
